# %%
# Import necessary libraries
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Flatten, BatchNormalization
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import MeanSquaredError, MeanAbsoluteError,categorical_crossentropy
from tensorflow.keras.metrics import MeanAbsoluteError, MeanSquaredError, Accuracy
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.metrics import accuracy_score,precision_score,recall_score,f1_score, confusion_matrix,classification_report
from imblearn.over_sampling import SMOTE

# %%
path=r"C:\Users\mrtat\Downloads\DL task\dataset\stroke.csv"
df=pd.read_csv(path)

# %%
df.head()
# Out:
#    gender       age  hypertension  heart_disease  ever_married  work_type  \
# 0     0.5  0.816895           0.0            1.0           1.0       0.50
# 1     0.0  0.743652           0.0            0.0           1.0       0.75
# 2     0.5  0.975586           0.0            1.0           1.0       0.50
# 3     0.0  0.597168           0.0            0.0           1.0       0.50
# 4     0.0  0.963379           1.0            0.0           1.0       0.75
#
#    Residence_type  avg_glucose_level       bmi  smoking_status  stroke
# 0             1.0           0.801265  0.301260        0.333333       1
# 1             0.0           0.679023  0.212981        0.666667       1
# 2             0.0           0.234512  0.254296        0.666667       1
# 3             1.0           0.536008  0.276060        1.000000       1
# 4             0.0           0.549349  0.156930        0.666667       1

# %%
df.tail()
# Out:
#       gender       age  hypertension  heart_disease  ever_married  work_type  \
# 9717     0.0  0.899548           1.0            0.0           1.0   0.532123
# 9718     0.0  0.866094           0.0            0.0           1.0   0.000000
# 9719     0.5  0.871179           0.0            0.0           1.0   0.500000
# 9720     0.0  0.916245           0.0            0.0           1.0   0.750000
# 9721     0.0  0.720902           0.0            0.0           1.0   0.750000
#
#       Residence_type  avg_glucose_level       bmi  smoking_status  stroke
# 9717             0.0           0.613801  0.281716        0.666667       1
# 9718             1.0           0.942631  0.321731        0.666667       1
# 9719             0.0           0.859567  0.332491        0.762415       1
# 9720             0.0           0.105444  0.217425        0.333333       1
# 9721             0.0           0.666253  0.248074        0.755415       1

# %%
df.isna().sum().sort_values(ascending=False)
# Out:
# gender               0
# age                  0
# hypertension         0
# heart_disease        0
# ever_married         0
# work_type            0
# Residence_type       0
# avg_glucose_level    0
# bmi                  0
# smoking_status       0
# stroke               0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9722 entries, 0 to 9721
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   gender             9722 non-null   float64
#  1   age                9722 non-null   float64
#  2   hypertension       9722 non-null   float64
#  3   heart_disease      9722 non-null   float64
#  4   ever_married       9722 non-null   float64
#  5   work_type          9722 non-null   float64
#  6   Residence_type     9722 non-null   float64
#  7   avg_glucose_level  9722 non-null   float64
#  8   bmi                9722 non-null   float64
#  9   smoking_status     9722 non-null   float64
#  10  stroke             9722 non-null   int64
# dtypes: float64(10), int64(1)
# memory usage: 835.6 KB

# %%
# Split features and target
X = df.drop(columns=['stroke'])  # Features
y = df['stroke']  # Target variable

# %%
# Split dataset into training (80%) and testing (20%)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=42, stratify=y)

# %%
sns.set(style="whitegrid")
plt.figure(figsize=(6, 4))
sns.countplot(x='stroke', data=df)
plt.title('Stroke Distribution\n')
plt.show()

# %%
print(df['stroke'].value_counts())
print(df['stroke'].value_counts(normalize=True))  # Shows percentages
# Out:
# stroke
# 1    4861
# 0    4861
# Name: count, dtype: int64
# stroke
# 1    0.5
# 0    0.5
# Name: proportion, dtype: float64

# %%
revenue_counts = df['stroke'].value_counts()
revenue_counts.plot(
    kind='pie',
    figsize=(6, 4),
    autopct='%1.1f%%',   # add in percentages
    startangle=90,       # start angle 90°   
    colors=["#eb72aa","#84c0fc"],  # Custom colors for the pie chart    
)

plt.title('Stroke Distribution\n')
plt.axis('equal')  # Sets the pie chart to look like a circle.
plt.legend(labels=revenue_counts.index, bbox_to_anchor=(1, 0))
plt.ylabel('')  # Hide y-label
plt.show()

# %%
def build_model():
    model = Sequential([
        Flatten(input_shape=(X_train.shape[1],)),
        
        Dense(128, activation='relu'),
        # Batch Normalization: Stabilizes and speeds up training
        BatchNormalization(),
        # Dropout: Randomly ignores 20% of neurons to prevent co-adaptation/overfitting
        Dropout(0.2),

        # Second Hidden Layer
        Dense(64, activation='relu'),
        BatchNormalization(),

        
        # Third Hidden Layer (Optional: Added for depth)
        Dense(32, activation='relu'),

        Dense(1, activation='sigmoid')
    ])

    
    

    model.compile(optimizer=Adam(learning_rate=0.001),
                  loss='binary_crossentropy',
                  metrics=['accuracy'])
    return model

# %%
model=build_model()
model.summary()
# Out:
# c:\Users\mrtat\AppData\Local\Programs\Python\Python313\Lib\site-packages\keras\src\layers\reshaping\flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential_15"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ flatten_15 (Flatten)            │ (None, 10)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_73 (Dense)                │ (None, 128)            │         1,408 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_10          │ (None, 128)            │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_21 (Dropout)            │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_74 (Dense)                │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_11          │ (None, 64)             │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_75 (Dense)                │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_76 (Dense)                │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 12,545 (49.00 KB)
#  Trainable params: 12,161 (47.50 KB)
#  Non-trainable params: 384 (1.50 KB)

# %%
print("\nTraining the model...")
history = model.fit(X_train, y_train,
                    epochs=50,  
                    batch_size=32,
                    validation_split=0.2,# Use 20% of training data for validation
                    callbacks=[
                        EarlyStopping(monitor='val_loss', patience=4, restore_best_weights=True),

                    ]

                    )
# Out:
# Training the model...
# Epoch 1/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.7664 - loss: 0.4864 - val_accuracy: 0.7766 - val_loss: 0.5402
# Epoch 2/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8007 - loss: 0.4351 - val_accuracy: 0.8074 - val_loss: 0.4304
# Epoch 3/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8075 - loss: 0.4154 - val_accuracy: 0.8206 - val_loss: 0.3829
# Epoch 4/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8087 - loss: 0.4095 - val_accuracy: 0.8286 - val_loss: 0.3691
# Epoch 5/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8167 - loss: 0.3989 - val_accuracy: 0.8331 - val_loss: 0.3607
# Epoch 6/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8214 - loss: 0.3911 - val_accuracy: 0.8411 - val_loss: 0.3580
# Epoch 7/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8328 - loss: 0.3759 - val_accuracy: 0.8486 - val_loss: 0.3326
# Epoch 8/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8368 - loss: 0.3692 - val_accuracy: 0.8423 - val_loss: 0.3495
# Epoch 9/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8423 - loss: 0.3581 - val_accuracy: 0.8600 - val_loss: 0.3182
# Epoch 10/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8410 - loss: 0.3544 - val_accuracy: 0.8629 - val_loss: 0.3069
# Epoch 11/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8500 - loss: 0.3365 - val_accuracy: 0.8640 - val_loss: 0.3023
# Epoch 12/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8554 - loss: 0.3339 - val_accuracy: 0.8806 - val_loss: 0.2929
# Epoch 13/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8481 - loss: 0.3305 - val_accuracy: 0.8697 - val_loss: 0.2941
# Epoch 14/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8547 - loss: 0.3284 - val_accuracy: 0.8651 - val_loss: 0.2951
# Epoch 15/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8578 - loss: 0.3184 - val_accuracy: 0.8874 - val_loss: 0.2822
# Epoch 16/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8663 - loss: 0.3187 - val_accuracy: 0.8697 - val_loss: 0.2968
# Epoch 17/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8747 - loss: 0.3054 - val_accuracy: 0.8840 - val_loss: 0.2722
# Epoch 18/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8697 - loss: 0.3024 - val_accuracy: 0.8863 - val_loss: 0.2750
# Epoch 19/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8721 - loss: 0.2997 - val_accuracy: 0.8903 - val_loss: 0.2710
# Epoch 20/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8758 - loss: 0.2990 - val_accuracy: 0.8869 - val_loss: 0.2646
# Epoch 21/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8784 - loss: 0.2882 - val_accuracy: 0.8874 - val_loss: 0.2599
# Epoch 22/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8794 - loss: 0.2891 - val_accuracy: 0.9023 - val_loss: 0.2604
# Epoch 23/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8817 - loss: 0.2812 - val_accuracy: 0.8931 - val_loss: 0.2571
# Epoch 24/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8791 - loss: 0.2816 - val_accuracy: 0.8829 - val_loss: 0.2661
# Epoch 25/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8813 - loss: 0.2813 - val_accuracy: 0.8983 - val_loss: 0.2497
# Epoch 26/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8903 - loss: 0.2721 - val_accuracy: 0.8926 - val_loss: 0.2720
# Epoch 27/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8881 - loss: 0.2718 - val_accuracy: 0.9034 - val_loss: 0.2468
# Epoch 28/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8911 - loss: 0.2653 - val_accuracy: 0.9011 - val_loss: 0.2577
# Epoch 29/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8881 - loss: 0.2688 - val_accuracy: 0.8949 - val_loss: 0.2523
# Epoch 30/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8913 - loss: 0.2629 - val_accuracy: 0.9120 - val_loss: 0.2404
# Epoch 31/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8888 - loss: 0.2668 - val_accuracy: 0.9000 - val_loss: 0.2431
# Epoch 32/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8856 - loss: 0.2614 - val_accuracy: 0.9023 - val_loss: 0.2486
# Epoch 33/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8950 - loss: 0.2544 - val_accuracy: 0.9114 - val_loss: 0.2384
# Epoch 34/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8931 - loss: 0.2578 - val_accuracy: 0.9063 - val_loss: 0.2390
# Epoch 35/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8938 - loss: 0.2569 - val_accuracy: 0.8926 - val_loss: 0.2633
# Epoch 36/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8927 - loss: 0.2559 - val_accuracy: 0.9063 - val_loss: 0.2380
# Epoch 37/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8977 - loss: 0.2532 - val_accuracy: 0.9103 - val_loss: 0.2305
# Epoch 38/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8966 - loss: 0.2505 - val_accuracy: 0.9069 - val_loss: 0.2364
# Epoch 39/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8971 - loss: 0.2467 - val_accuracy: 0.9103 - val_loss: 0.2239
# Epoch 40/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8973 - loss: 0.2454 - val_accuracy: 0.9171 - val_loss: 0.2264
# Epoch 41/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8976 - loss: 0.2440 - val_accuracy: 0.9171 - val_loss: 0.2172
# Epoch 42/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8998 - loss: 0.2466 - val_accuracy: 0.9189 - val_loss: 0.2126
# Epoch 43/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8981 - loss: 0.2420 - val_accuracy: 0.9183 - val_loss: 0.2165
# Epoch 44/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9003 - loss: 0.2452 - val_accuracy: 0.9149 - val_loss: 0.2309
# Epoch 45/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9017 - loss: 0.2360 - val_accuracy: 0.9194 - val_loss: 0.2119
# Epoch 46/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8993 - loss: 0.2366 - val_accuracy: 0.9166 - val_loss: 0.2255
# Epoch 47/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9048 - loss: 0.2346 - val_accuracy: 0.9086 - val_loss: 0.2346
# Epoch 48/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8983 - loss: 0.2425 - val_accuracy: 0.9149 - val_loss: 0.2204
# Epoch 49/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9051 - loss: 0.2354 - val_accuracy: 0.9286 - val_loss: 0.2101
# Epoch 50/50
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9037 - loss: 0.2319 - val_accuracy: 0.9240 - val_loss: 0.2212

# %%
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.show()

# %%
# Predict probabilities
y_pred_prob = model.predict(X_test)

# Convert probabilities to binary class labels
y_pred = (y_pred_prob > 0.5).astype(int)

# Compute confusion matrix
cm = confusion_matrix(y_test, y_pred)

# Optional: plot
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title("Confusion Matrix for Heart Failure Prediction")
# Out:
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Text(0.5, 1.0, 'Confusion Matrix for Heart Failure Prediction')

# %%
print("Classification Report:\n", classification_report(y_test, y_pred))
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.97      0.88      0.92       472
#            1       0.89      0.97      0.93       501
#
#     accuracy                           0.93       973
#    macro avg       0.93      0.93      0.93       973
# weighted avg       0.93      0.93      0.93       973
